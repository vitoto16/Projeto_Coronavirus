# %%
import pandas as pd

# %%
df = pd.read_excel('out_corona.xlsx')

# %%
df
# Out:
#      Unnamed: 0  Total Cases  New Cases  Total Deaths  New Deaths  \
# 0           USA      1430348          0         85197           0
# 1             0            0          0             0           0
# 2         Spain       271095          0         27104           0
# 3        Russia       242271          0          2212           0
# 4            UK       229705          0         33186           0
# 5         Italy       222104          0         31106           0
# 6        Brazil       189157          0         13158           0
# 7        France       178060          0         27074           0
# 8       Germany       174098          0          7861           0
# 9        Turkey       143114          0          3952           0
# 10         Iran       112725          0          6783           0
# 11        China        82929          3          4633           0
# 12        India        78055          0          2551           0
# ...

# %%
df.loc[5]
# Out:
# Unnamed: 0             Italy
# Total Cases           222104
# New Cases                  0
# Total Deaths           31106
# New Deaths                 0
# Total Recovered       112541
# Active Cases           78457
# Serious, Critical        893
# Tot Cases/ 1M pop       3673
# Deaths/ 1M pop           514
# Total Tests          2735628
# Tests/ 1M pop          45246
# Name: 5, dtype: object

# %%
df.loc[5, 'Total Cases']
# Out:
# 222104

# %%
import numpy as np

# %%
df.iloc[:, 1]
# Out:
# 0     1430348
# 1           0
# 2      271095
# 3      242271
# 4      229705
# 5      222104
# 6      189157
# 7      178060
# 8      174098
# 9      143114
# 10     112725
# 11      82929
# 12      78055
# 13      76306
# 14      72278
# 15      53981
# 16      44830
# 17      43211
# 18      40186
# 19      35298
# 20      34381
# 21      30486
# 22      30413
# 23      28132
# 24      27909
# 25      26539
# 26      25825
# 27      25346
# Name: Total Cases, dtype: int64

# %%
total_cases = df.iloc[:, 1]
total_deaths = df.iloc[:, 3]
total_tests = df.iloc[:, 10]

# %%
for i in total_tests:
    print(type(i))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
soma = total_cases.sum()

# %%
soma
# Out:
# 3948782

# %%
df['Porcentagem Total Cases'] = total_cases / soma

# %%
df.head()
# Out:
#   Unnamed: 0  Total Cases  New Cases  Total Deaths  New Deaths  \
# 0        USA      1430348          0         85197           0
# 1          0            0          0             0           0
# 2      Spain       271095          0         27104           0
# 3     Russia       242271          0          2212           0
# 4         UK       229705          0         33186           0
#
#    Total Recovered  Active Cases  Serious, Critical  Tot Cases/ 1M pop  \
# 0         310259.0       1034892              16349               4321
# 1              0.0             0                  0                  0
# 2         183227.0         60764               1534               5798
# 3          48003.0        192056               2300               1660
# 4              NaN        196175               1559               3384
#
#    Deaths/ 1M pop  Total Tests  Tests/ 1M pop  Porcentagem Total Cases
# 0             257     10269996          31027                 0.362225
# ...
